# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Обзор данных

# %% [markdown]
# Для считывания данных используется функция `pd.read_csv`. У этой функции много аргументов (см. документацию), первый из которых - название считываемого файла с данными, второй - sep - разделитель, по умолчанию это запятая. Данные в csv файлах (обычно, но не всегда) записаны в виде "таблицы". Одна запись - одна строка, данные столбцов разделяются запятыми.

# %% [markdown]
# Для работы с файлом его, как и обычный текстовый файл (впрочем, это и есть обычный текстовый файл!), удобнее положить в ту же директорию, где лежит ноутбук. Затем вы можете прямо через jupyter открыть файл `csv` и увидеть, как он выглядит.

# %%
f = pd.read_csv("telecom_churn.csv")

# %% [markdown]
# Посмотреть начало и конец таблицы (по умолчанию 5 строк, но это настраиваемый параметр) - функции `head` и `tail`. Описание данных - `describe`, `info`. Размер таблицы - `shape`, названия колонок - `columns`. Обратите внимание, что `columns` возвращает итерируемый объект.

# %%
f.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False

# %%
f.head(7)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
# 5    AL             118        510                Yes              No
# 6    MA             121        510                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
# 5                      0              223.4               98
# 6                     24              218.2               88
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
# 5             37.98              220.6              101             18.75
# 6             37.09              348.5              108             29.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
# 5                203.9                118                9.18
# 6                212.6                118                9.57
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
# 5                 6.3                 6               1.70
# 6                 7.5                 7               2.03
#
#    Customer service calls  Churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False
# 5                       0  False
# 6                       3  False

# %%
f.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3328             26.55              215.5              126             18.32
# 3329             39.29              153.4               55             13.04
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 3328                       2  False
# 3329                       3  False
# 3330                       2  False
# 3331                       2  False
# 3332                       0  False

# %%
f.tail(7)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3326    OH              96        415                 No              No
# 3327    SC              79        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3326                      0              106.6              128
# 3327                      0              134.7               98
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3326             18.12              284.8               87             24.21
# 3327             22.90              189.7               68             16.12
# 3328             26.55              215.5              126             18.32
# 3329             39.29              153.4               55             13.04
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 3326                178.9                 92                8.05
# 3327                221.4                128                9.96
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 3326                14.9                 7               4.02
# 3327                11.8                 5               3.19
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 3326                       1  False
# 3327                       2  False
# 3328                       2  False
# 3329                       3  False
# 3330                       2  False
# 3331                       2  False
# 3332                       0  False

# %%
f.tail(100)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3233    OK             112        415                 No              No
# 3234    DE              75        510                 No             Yes
# 3235    AZ              97        408                 No             Yes
# 3236    AK             121        408                 No             Yes
# 3237    MI             142        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3233                      0              166.0               79
# 3234                     28              200.6               96
# 3235                     25              141.0              101
# 3236                     34              245.0               95
# 3237                      0              140.8              140
# ...                     ...                ...              ...
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3233             28.22               74.6              100              6.34
# 3234             34.10              164.1              111             13.95
# 3235             23.97              212.0               85             18.02
# 3236             41.65              216.9               66             18.44
# 3237             23.94              228.6              119             19.43
# ...                ...                ...              ...               ...
# 3328             26.55              215.5              126             18.32
# 3329             39.29              153.4               55             13.04
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 3233                247.9                 74               11.16
# 3234                169.6                153                7.63
# 3235                175.2                138                7.88
# 3236                112.4                125                5.06
# 3237                152.9                 88                6.88
# ...                   ...                ...                 ...
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 3233                 6.3                 7               1.70
# 3234                 2.5                 5               0.68
# 3235                 4.9                 2               1.32
# 3236                 7.5                 8               2.03
# 3237                10.9                 7               2.94
# ...                  ...               ...                ...
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 3233                       0  False
# 3234                       1  False
# 3235                       3  False
# 3236                       0  False
# 3237                       1  False
# ...                      ...    ...
# 3328                       2  False
# 3329                       3  False
# 3330                       2  False
# 3331                       2  False
# 3332                       0  False
#
# [100 rows x 20 columns]

# %%
f.shape
# Out:
# (3333, 20)

# %%
f.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
f.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# std          20.069084          9.259435          50.713844        19.922625
# min           0.000000          0.000000           0.000000         0.000000
# 25%          87.000000         24.430000         166.600000        87.000000
# 50%         101.000000         30.500000         201.400000       100.000000
# 75%         114.000000         36.790000         235.300000       114.000000
# max         165.000000         59.640000         363.700000       170.000000
#
#        Total eve charge  Total night minutes  Total night calls  \
# count       3333.000000          3333.000000        3333.000000
# mean          17.083540           200.872037         100.107711
# std            4.310668            50.573847          19.568609
# min            0.000000            23.200000          33.000000
# 25%           14.160000           167.000000          87.000000
# 50%           17.120000           201.200000         100.000000
# 75%           20.000000           235.300000         113.000000
# max           30.910000           395.000000         175.000000
#
#        Total night charge  Total intl minutes  Total intl calls  \
# count         3333.000000         3333.000000       3333.000000
# mean             9.039325           10.237294          4.479448
# std              2.275873            2.791840          2.461214
# min              1.040000            0.000000          0.000000
# 25%              7.520000            8.500000          3.000000
# 50%              9.050000           10.300000          4.000000
# 75%             10.590000           12.100000          6.000000
# max             17.770000           20.000000         20.000000
#
#        Total intl charge  Customer service calls
# count        3333.000000             3333.000000
# mean            2.764581                1.562856
# std             0.753773                1.315491
# min             0.000000                0.000000
# 25%             2.300000                1.000000
# 50%             2.780000                1.000000
# 75%             3.270000                2.000000
# max             5.400000                9.000000

# %%
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
# RangeIndex: 3333 entries, 0 to 3332
#
# Data columns (total 20 columns):
#
#  #   Column                  Non-Null Count  Dtype
#
# ---  ------                  --------------  -----
#
#  0   State                   3333 non-null   object
#
#  1   Account length          3333 non-null   int64
#
#  2   Area code               3333 non-null   int64
#
#  3   International plan      3333 non-null   object
#
#  4   Voice mail plan         3333 non-null   object
#
#  5   Number vmail messages   3333 non-null   int64
#
#  6   Total day minutes       3333 non-null   float64
#
#  7   Total day calls         3333 non-null   int64
#
#  8   Total day charge        3333 non-null   float64
#
#  9   Total eve minutes       3333 non-null   float64
#
#  10  Total eve calls         3333 non-null   int64
#
#  11  Total eve charge        3333 non-null   float64
#
#  12  Total night minutes     3333 non-null   float64
#
#  13  Total night calls       3333 non-null   int64
#
#  14  Total night charge      3333 non-null   float64
#
#  15  Total intl minutes      3333 non-null   float64
#
#  16  Total intl calls        3333 non-null   int64
#
#  17  Total intl charge       3333 non-null   float64
#
#  18  Customer service calls  3333 non-null   int64
#
#  19  Churn                   3333 non-null   bool
#
# dtypes: bool(1), float64(8), int64(8), object(3)
#
# memory usage: 498.1+ KB

# %% [markdown]
# Небольшое, но важное отступление. Глубоко понимать это пока не обязательно. Обратите внимание, что функция `print` возвращает строковое представление объекта и она не необходима, чтобы вывести объект. 2 ячейки сработают одинаково:

# %%
a = 1
print(a)
# Out:
# 1

# %%
a = 1
a
# Out:
# 1

# %% [markdown]
# При этом для некоторых объектов (для которых стандартные функции `__str__` и `__repr__` возвращают разные значения) два способа вывода сработают несколько по-разному:

# %%
a = np.array([1.0, 2.0])
print(a)
# Out:
# [1. 2.]

# %%
a = np.array([1.0, 2.0])
a
# Out:
# array([1., 2.])

# %% [markdown]
# Такая же ситуация с pandas dataframe'ами. Без print получится красивее, чем с ним, но фактически это одно и то же:

# %%
print(f)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
#
# 0       KS             128        415                 No             Yes
#
# 1       OH             107        415                 No             Yes
#
# 2       NJ             137        415                 No              No
#
# 3       OH              84        408                Yes              No
#
# 4       OK              75        415                Yes              No
#
# ...    ...             ...        ...                ...             ...
#
# 3328    AZ             192        415                 No             Yes
#
# 3329    WV              68        415                 No              No
#
# 3330    RI              28        510                 No              No
#
# 3331    CT             184        510                Yes              No
#
# 3332    TN              74        415                 No             Yes
#
#
#
#       Number vmail messages  Total day minutes  Total day calls  \
#
# 0                        25              265.1              110
#
# 1                        26              161.6              123
#
# 2                         0              243.4              114
#
# 3                         0              299.4               71
#
# 4                         0              166.7              113
#
# ...                     ...                ...              ...
#
# 3328                     36              156.2               77
#
# 3329                      0              231.1               57
#
# 3330                      0              180.8              109
#
# 3331                      0              213.8              105
#
# 3332                     25              234.4              113
#
#
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
#
# 0                45.07              197.4               99             16.78
#
# 1                27.47              195.5              103             16.62
#
# 2                41.38              121.2              110             10.30
#
# 3                50.90               61.9               88              5.26
#
# 4                28.34              148.3              122             12.61
#
# ...                ...                ...              ...               ...
#
# 3328             26.55              215.5              126             18.32
#
# 3329             39.29              153.4               55             13.04
#
# 3330             30.74              288.8               58             24.55
#
# 3331             36.35              159.6               84             13.57
#
# 3332             39.85              265.9               82             22.60
#
#
#
#       Total night minutes  Total night calls  Total night charge  \
#
# 0                   244.7                 91               11.01
#
# 1                   254.4                103               11.45
#
# 2                   162.6                104                7.32
#
# 3                   196.9                 89                8.86
#
# 4                   186.9                121                8.41
#
# ...                   ...                ...                 ...
#
# 3328                279.1                 83               12.56
#
# 3329                191.3                123                8.61
#
# 3330                191.9                 91                8.64
#
# 3331                139.2                137                6.26
#
# 3332                241.4                 77               10.86
#
#
#
#       Total intl minutes  Total intl calls  Total intl charge  \
#
# 0                   10.0                 3               2.70
#
# 1                   13.7                 3               3.70
#
# 2                   12.2                 5               3.29
#
# 3                    6.6                 7               1.78
#
# 4                   10.1                 3               2.73
#
# ...                  ...               ...                ...
#
# 3328                 9.9                 6               2.67
#
# 3329                 9.6                 4               2.59
#
# 3330                14.1                 6               3.81
#
# 3331                 5.0                10               1.35
#
# 3332                13.7                 4               3.70
#
#
#
#       Customer service calls  Churn
#
# 0                          1  False
#
# 1                          1  False
#
# 2                          0  False
#
# 3                          2  False
#
# 4                          3  False
#
# ...                      ...    ...
#
# 3328                       2  False
#
# 3329                       3  False
#
# 3330                       2  False
#
# 3331                       2  False
#
# 3332                       0  False
#
#
#
# [3333 rows x 20 columns]

# %%
f
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1              110
# 1                        26              161.6              123
# 2                         0              243.4              114
# 3                         0              299.4               71
# 4                         0              166.7              113
# ...                     ...                ...              ...
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0                45.07              197.4               99             16.78
# 1                27.47              195.5              103             16.62
# 2                41.38              121.2              110             10.30
# 3                50.90               61.9               88              5.26
# 4                28.34              148.3              122             12.61
# ...                ...                ...              ...               ...
# 3328             26.55              215.5              126             18.32
# 3329             39.29              153.4               55             13.04
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# ...                   ...                ...                 ...
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 0                          1  False
# 1                          1  False
# 2                          0  False
# 3                          2  False
# 4                          3  False
# ...                      ...    ...
# 3328                       2  False
# 3329                       3  False
# 3330                       2  False
# 3331                       2  False
# 3332                       0  False
#
# [3333 rows x 20 columns]

# %% [markdown]
# 2 варианта синтаксиса для просмотра содержимого столбца:

# %%
f.State
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: object

# %%
f['State']
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: object

# %% [markdown]
# Обратите внимание, что таблица и столбцы имеют разный тип:

# %%
type(f), type(f.State), type(f['State'])
# Out:
# (pandas.core.frame.DataFrame,
#  pandas.core.series.Series,
#  pandas.core.series.Series)

# %% [markdown]
# Тем не менее, мы можем сделать именно датафрейм из одного столбца следующим образом:

# %%
f[['State']]
# Out:
#      State
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
# ...    ...
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
#
# [3333 rows x 1 columns]

# %%
type(f[['State']]), type(f['State'])
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %% [markdown]
# Это способ обращения к "срезам" таблицы по названиям столбцов. Еще пример:

# %%
f[['State', 'Churn']]
# Out:
#      State  Churn
# 0       KS  False
# 1       OH  False
# 2       NJ  False
# 3       OH  False
# 4       OK  False
# ...    ...    ...
# 3328    AZ  False
# 3329    WV  False
# 3330    RI  False
# 3331    CT  False
# 3332    TN  False
#
# [3333 rows x 2 columns]

# %% [markdown]
# Просмотр уникальных значений в столбце и их числа:

# %%
f.State.unique()
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'LA', 'WV', 'IN', 'RI',
#        'IA', 'MT', 'NY', 'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'SC',
#        'NE', 'WY', 'HI', 'IL', 'NH', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR',
#        'MI', 'DE', 'UT', 'CA', 'MN', 'SD', 'NC', 'WA', 'NM', 'NV', 'DC',
#        'KY', 'ME', 'MS', 'TN', 'PA', 'CT', 'ND'], dtype=object)

# %%
f.State.nunique()
# Out:
# 51

# %% [markdown]
# Обращение к элементу ообъекта `pd.Series`:

# %%
f.State[0]
# Out:
# 'KS'

# %% [markdown]
# Полный набор функций, применимых к столбцу можно посмотреть следующим образом. Здесь используется стандартная функция `__dir__()`, которая выводит список атрибутов и методов объекта.

# %%
f.State.__dir__()
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_add_numeric_operations',
#  '_add_series_or_dataframe_operations',
#  '_agg_by_level',
#  '_agg_examples_doc',
#  '_agg_see_also_doc',
#  '_aggregate',
#  '_aggregate_multiple_funcs',
#  '_align_frame',
#  '_align_series',
#  '_binop',
#  '_builtin_table',
#  '_can_hold_na',
#  '_check_inplace_setting',
#  '_check_is_chained_assignment_possible',
#  '_check_label_or_level_ambiguity',
#  '_check_setitem_copy',
#  '_clear_item_cache',
#  '_clip_with_one_bound',
#  '_clip_with_scalar',
#  '_consolidate',
#  '_consolidate_inplace',
#  '_construct_axes_dict',
#  '_construct_axes_from_arguments',
#  '_construct_result',
#  '_constructor',
#  '_constructor_expanddim',
#  '_constructor_sliced',
#  '_convert',
#  '_convert_dtypes',
#  '_cython_table',
#  '_data',
#  '_deprecations',
#  '_dir_additions',
#  '_dir_deletions',
#  '_drop_axis',
#  '_drop_labels_or_levels',
#  '_find_valid_index',
#  '_get_axis',
#  '_get_axis_name',
#  '_get_axis_number',
#  '_get_axis_resolvers',
#  '_get_block_manager_axis',
#  '_get_bool_data',
#  '_get_cacher',
#  '_get_cleaned_column_resolvers',
#  '_get_cython_func',
#  '_get_index_resolvers',
#  '_get_item_cache',
#  '_get_label_or_level_values',
#  '_get_numeric_data',
#  '_get_value',
#  '_get_values',
#  '_get_values_tuple',
#  '_get_with',
#  '_gotitem',
#  '_index',
#  '_indexed_same',
#  '_info_axis',
#  '_info_axis_name',
#  '_info_axis_number',
#  '_init_dict',
#  '_init_mgr',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_builtin_func',
#  '_is_cached',
#  '_is_copy',
#  '_is_label_or_level_reference',
#  '_is_label_reference',
#  '_is_level_reference',
#  '_is_mixed_type',
#  '_is_view',
#  '_iset_item',
#  '_ix',
#  '_ixs',
#  '_map_values',
#  '_maybe_cache_changed',
#  '_maybe_update_cacher',
#  '_metadata',
#  '_needs_reindex_multi',
#  '_obj_with_exclusions',
#  '_protect_consolidate',
#  '_reduce',
#  '_reindex_axes',
#  '_reindex_indexer',
#  '_reindex_multi',
#  '_reindex_with_indexers',
#  '_repr_data_resource_',
#  '_repr_latex_',
#  '_reset_cache',
#  '_reset_cacher',
#  '_selected_obj',
#  '_selection',
#  '_selection_list',
#  '_selection_name',
#  '_set_as_cached',
#  '_set_axis',
#  '_set_axis_name',
#  '_set_is_copy',
#  '_set_item',
#  '_set_labels',
#  '_set_name',
#  '_set_value',
#  '_set_values',
#  '_set_with',
#  '_set_with_engine',
#  '_slice',
#  '_stat_axis',
#  '_stat_axis_name',
#  '_stat_axis_number',
#  '_take_with_is_copy',
#  '_to_dict_of_blocks',
#  '_try_aggregate_string_function',
#  '_typ',
#  '_update_inplace',
#  '_validate_dtype',
#  '_values',
#  '_where',
#  'abs',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'agg',
#  'aggregate',
#  'align',
#  'all',
#  'any',
#  'append',
#  'apply',
#  'argmax',
#  'argmin',
#  'argsort',
#  'array',
#  'asfreq',
#  'asof',
#  'astype',
#  'at',
#  'at_time',
#  'attrs',
#  'autocorr',
#  'axes',
#  'backfill',
#  'between',
#  'between_time',
#  'bfill',
#  'bool',
#  'clip',
#  'combine',
#  'combine_first',
#  'compare',
#  'convert_dtypes',
#  'copy',
#  'corr',
#  'count',
#  'cov',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'describe',
#  'diff',
#  'div',
#  'divide',
#  'divmod',
#  'dot',
#  'drop',
#  'drop_duplicates',
#  'droplevel',
#  'dropna',
#  'dtype',
#  'dtypes',
#  'duplicated',
#  'empty',
#  'eq',
#  'equals',
#  'ewm',
#  'expanding',
#  'explode',
#  'factorize',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'first_valid_index',
#  'floordiv',
#  'ge',
#  'get',
#  'groupby',
#  'gt',
#  'hasnans',
#  'head',
#  'hist',
#  'iat',
#  'idxmax',
#  'idxmin',
#  'iloc',
#  'index',
#  'infer_objects',
#  'interpolate',
#  'is_monotonic',
#  'is_monotonic_decreasing',
#  'is_monotonic_increasing',
#  'is_unique',
#  'isin',
#  'isna',
#  'isnull',
#  'item',
#  'items',
#  'iteritems',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'last',
#  'last_valid_index',
#  'le',
#  'loc',
#  'lt',
#  'mad',
#  'map',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'memory_usage',
#  'min',
#  'mod',
#  'mode',
#  'mul',
#  'multiply',
#  'name',
#  'nbytes',
#  'ndim',
#  'ne',
#  'nlargest',
#  'notna',
#  'notnull',
#  'nsmallest',
#  'nunique',
#  'pad',
#  'pct_change',
#  'pipe',
#  'plot',
#  'pop',
#  'pow',
#  'prod',
#  'product',
#  'quantile',
#  'radd',
#  'rank',
#  'ravel',
#  'rdiv',
#  'rdivmod',
#  'reindex',
#  'reindex_like',
#  'rename',
#  'rename_axis',
#  'reorder_levels',
#  'repeat',
#  'replace',
#  'resample',
#  'reset_index',
#  'rfloordiv',
#  'rmod',
#  'rmul',
#  'rolling',
#  'round',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'sample',
#  'searchsorted',
#  'sem',
#  'set_axis',
#  'shape',
#  'shift',
#  'size',
#  'skew',
#  'slice_shift',
#  'sort_index',
#  'sort_values',
#  'squeeze',
#  'std',
#  'str',
#  'sub',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'swaplevel',
#  'tail',
#  'take',
#  'to_clipboard',
#  'to_csv',
#  'to_dict',
#  'to_excel',
#  'to_frame',
#  'to_hdf',
#  'to_json',
#  'to_latex',
#  'to_list',
#  'to_markdown',
#  'to_numpy',
#  'to_period',
#  'to_pickle',
#  'to_sql',
#  'to_string',
#  'to_timestamp',
#  'to_xarray',
#  'transform',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tz_convert',
#  'tz_localize',
#  'unique',
#  'unstack',
#  'update',
#  'value_counts',
#  'values',
#  'var',
#  'view',
#  'where',
#  'xs']

# %% [markdown]
# С `pd.DataFrame` привычный способ обращения по индексам не сработает:

# %%
f[0][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-dadc704e8d1c> in <module>
# ----> 1 f[0][0]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 0

# %% [markdown]
# Основной способ - использование `loc` и `iloc`. `loc` дает индексацию по "настоящим" индексам - названиям столбцов и названиям строк. В нашем случае, названия строк - целые числа, как обычные индексы. `iloc` позволяет осуществлять стандартную численную индексацию, как для `numpy` массивов.

# %%
f.iloc[0] # первая строка
# Out:
# State                        KS
# Account length              128
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        25
# Total day minutes         265.1
# Total day calls             110
# Total day charge          45.07
# Total eve minutes         197.4
# Total eve calls              99
# Total eve charge          16.78
# Total night minutes       244.7
# Total night calls            91
# Total night charge        11.01
# Total intl minutes           10
# Total intl calls              3
# Total intl charge           2.7
# Customer service calls        1
# Churn                     False
# Name: 0, dtype: object

# %%
f.iloc[0][0]
# Out:
# 'KS'

# %%
f.iloc[0, 0]
# Out:
# 'KS'

# %%
f.iloc[[0, 0]]
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 0    KS             128        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 0                     25              265.1              110
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 0             45.07              197.4               99             16.78
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 0                244.7                 91               11.01
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
# 0                10.0                 3                2.7
#
#    Customer service calls  Churn
# 0                       1  False
# 0                       1  False

# %%
f.iloc[[1, 2, 5, 1]]
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 5    AL             118        510                Yes              No
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 1                     26              161.6              123
# 2                      0              243.4              114
# 5                      0              223.4               98
# 1                     26              161.6              123
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 5             37.98              220.6              101             18.75
# 1             27.47              195.5              103             16.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 5                203.9                118                9.18
# 1                254.4                103               11.45
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 5                 6.3                 6               1.70
# 1                13.7                 3               3.70
#
#    Customer service calls  Churn
# 1                       1  False
# 2                       0  False
# 5                       0  False
# 1                       1  False

# %%
f.loc[[1, 2, 5, 1]]
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 5    AL             118        510                Yes              No
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 1                     26              161.6              123
# 2                      0              243.4              114
# 5                      0              223.4               98
# 1                     26              161.6              123
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 5             37.98              220.6              101             18.75
# 1             27.47              195.5              103             16.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 5                203.9                118                9.18
# 1                254.4                103               11.45
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 5                 6.3                 6               1.70
# 1                13.7                 3               3.70
#
#    Customer service calls  Churn
# 1                       1  False
# 2                       0  False
# 5                       0  False
# 1                       1  False

# %%
f.loc[[1, 2, 5, 1], ["State", "Account length"]]
# Out:
#   State  Account length
# 1    OH             107
# 2    NJ             137
# 5    AL             118
# 1    OH             107

# %%
f.iloc[[1, 2, 5, 1], [0, 1]]
# Out:
#   State  Account length
# 1    OH             107
# 2    NJ             137
# 5    AL             118
# 1    OH             107

# %% [markdown]
# Следующая ячейка вернет ошибку:

# %%
f.iloc[[1, 2, 5, 1], ["State", "Account length"]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-f118c8b0c674> in <module>
# ----> 1 f.iloc[[1, 2, 5, 1], ["State", "Account length"]]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1441     def _getitem_tuple(self, tup: Tuple):
#    1442
# -> 1443         self._has_valid_tuple(tup)
#    1444         try:
#    1445             return self._getitem_lowerdim(tup)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     700                 raise IndexingError("Too many indexers")
#     701             try:
# --> 702                 self._validate_key(k, i)
#     703             except ValueError as err:
#     704                 raise ValueError(
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1361             # check that the key has a numeric dtype
#    1362             if not is_numeric_dtype(arr.dtype):
# -> 1363                 raise IndexError(f".iloc requires numeric indexers, got {arr}")
#    1364
#    1365             # check that the key does not exceed the maximum size of the index
#
# IndexError: .iloc requires numeric indexers, got ['State' 'Account length']

# %%
f.iloc[:5, :4]
# Out:
#   State  Account length  Area code International plan
# 0    KS             128        415                 No
# 1    OH             107        415                 No
# 2    NJ             137        415                 No
# 3    OH              84        408                Yes
# 4    OK              75        415                Yes

# %%
f.loc[:, ["State", "Account length"]]
# Out:
#      State  Account length
# 0       KS             128
# 1       OH             107
# 2       NJ             137
# 3       OH              84
# 4       OK              75
# ...    ...             ...
# 3328    AZ             192
# 3329    WV              68
# 3330    RI              28
# 3331    CT             184
# 3332    TN              74
#
# [3333 rows x 2 columns]

# %%
f.loc[4:9, ["State", "Account length", "Area code", "International plan"]]
# Out:
#   State  Account length  Area code International plan
# 4    OK              75        415                Yes
# 5    AL             118        510                Yes
# 6    MA             121        510                 No
# 7    MO             147        415                Yes
# 8    LA             117        408                 No
# 9    WV             141        415                Yes

# %% [markdown]
# Обратите внимание, что `loc` включает и строки соответствующие и начальному, и конечному индексам.

# %% [markdown]
# Сохраним этот датафрейм в новую переменную и рассмотрим отличие loc и iloc в работе по целочисленным индексам строк

# %%
new_f = f.loc[4:9, ["State", "Account length", "Area code", "International plan"]]

# %%
new_f.iloc[:5]
# Out:
#   State  Account length  Area code International plan
# 4    OK              75        415                Yes
# 5    AL             118        510                Yes
# 6    MA             121        510                 No
# 7    MO             147        415                Yes
# 8    LA             117        408                 No

# %%
new_f.loc[:5]
# Out:
#   State  Account length  Area code International plan
# 4    OK              75        415                Yes
# 5    AL             118        510                Yes

# %% [markdown]
# **Упражнение 1.** Объясните различие поведения `loc` и `iloc` для `new_f`.

# %%
f.iloc[-:-1]
# Out:
#   File "<ipython-input-46-46a2eb09159e>", line 1
#     f.iloc[-:-1]
#             ^
# SyntaxError: invalid syntax

# %%
f.iloc[-2:-1]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3331    CT             184        510                Yes              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3331                      0              213.8              105
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3331             36.35              159.6               84             13.57
#
#       Total night minutes  Total night calls  Total night charge  \
# 3331                139.2                137                6.26
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 3331                 5.0                10               1.35
#
#       Customer service calls  Churn
# 3331                       2  False

# %% [markdown]
# #### Создание датафрейма и присваивание по индексам

# %%
df = pd.DataFrame({"A": [1, 2, 3], "B": [4, 5, 6]}, index = ["first", "second", "third"])
df
# Out:
#         A  B
# first   1  4
# second  2  5
# third   3  6

# %%
df.iloc[0, 0] = 100
df
# Out:
#           A  B
# first   100  4
# second    2  5
# third     3  6

# %%
df.loc["second", "B"] = 31
df
# Out:
#           A   B
# first   100   4
# second    2  31
# third     3   6

# %%
df.iloc[2] = 5
df
# Out:
#           A   B
# first   100   4
# second    2  31
# third     5   5

# %%
df.loc["B"] = 0
df
# Out:
#           A   B
# first   100   4
# second    2  31
# third     5   5
# B         0   0

# %%
df.loc[:, "B"] = 0
df
# Out:
#           A  B
# first   100  0
# second    2  0
# third     5  0
# B         0  0

# %%
df = pd.DataFrame({"A": [1, 2, 3, 4], "B": [5, 6, 7, 8]})
df
# Out:
#    A  B
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %%
df.iloc[1:2, :] = -1
df
# Out:
#    A  B
# 0  1  5
# 1 -1 -1
# 2  3  7
# 3  4  8

# %%
df.loc[1:2, :] = -2
df
# Out:
#    A  B
# 0  1  5
# 1 -2 -2
# 2 -2 -2
# 3  4  8

# %% [markdown]
# Еще раз убеждаемся, что `loc` включает оба конца "среза", а `iloc` - полуинтервал, как например обычные срезы.

# %% [markdown]
# #### Создание нового столбца

# %%
df["C"] = 1
df
# Out:
#    A  B  C
# 0  1  5  1
# 1 -2 -2  1
# 2 -2 -2  1
# 3  4  8  1

# %%
df["D"] = df["A"] + df["B"]
df
# Out:
#    A  B  C   D
# 0  1  5  1   6
# 1 -2 -2  1  -4
# 2 -2 -2  1  -4
# 3  4  8  1  12

# %%
df["E"] = df["D"].apply(lambda x: x ** 2)
df
# Out:
#    A  B  C   D    E
# 0  1  5  1   6   36
# 1 -2 -2  1  -4   16
# 2 -2 -2  1  -4   16
# 3  4  8  1  12  144

# %%
df["F"] = df[["A", "C", "E"]].apply(lambda x: x.sum(), axis=1)
df
# Out:
#    A  B  C   D    E    F
# 0  1  5  1   6   36   38
# 1 -2 -2  1  -4   16   15
# 2 -2 -2  1  -4   16   15
# 3  4  8  1  12  144  149

# %% [markdown]
# **Упражнение 2.** Объясните последний результат.

# %% [markdown]
# ## Срезы с условиями и аггрегация

# %%
f[f.Churn == True]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 10      IN              65        415                 No              No
# 15      NY             161        415                 No              No
# 21      CO              77        408                 No              No
# 33      AZ              12        408                 No              No
# 41      MD             135        408                Yes             Yes
# ...    ...             ...        ...                ...             ...
# 3301    CA              84        415                 No              No
# 3304    IL              71        510                Yes              No
# 3320    GA             122        510                Yes              No
# 3322    MD              62        408                 No              No
# 3323    IN             117        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 10                        0              129.1              137
# 15                        0              332.9               67
# 21                        0               62.4               89
# 33                        0              249.6              118
# 41                       41              173.1               85
# ...                     ...                ...              ...
# 3301                      0              280.0              113
# 3304                      0              186.1              114
# 3320                      0              140.0              101
# 3322                      0              321.1              105
# 3323                      0              118.4              126
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 10               21.95              228.5               83             19.42
# 15               56.59              317.8               97             27.01
# 21               10.61              169.9              121             14.44
# 33               42.43              252.4              119             21.45
# 41               29.43              203.9              107             17.33
# ...                ...                ...              ...               ...
# 3301             47.60              202.2               90             17.19
# 3304             31.64              198.6              140             16.88
# 3320             23.80              196.4               77             16.69
# 3322             54.59              265.5              122             22.57
# 3323             20.13              249.3               97             21.19
#
#       Total night minutes  Total night calls  Total night charge  \
# 10                  208.8                111                9.40
# 15                  160.6                128                7.23
# 21                  209.6                 64                9.43
# 33                  280.2                 90               12.61
# 41                  122.2                 78                5.50
# ...                   ...                ...                 ...
# 3301                156.8                103                7.06
# 3304                206.5                 80                9.29
# 3320                120.1                133                5.40
# 3322                180.5                 72                8.12
# 3323                227.0                 56               10.22
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 10                  12.7                 6               3.43
# 15                   5.4                 9               1.46
# 21                   5.7                 6               1.54
# 33                  11.8                 3               3.19
# 41                  14.6                15               3.94
# ...                  ...               ...                ...
# 3301                10.4                 4               2.81
# 3304                13.8                 5               3.73
# 3320                 9.7                 4               2.62
# 3322                11.5                 2               3.11
# 3323                13.6                 3               3.67
#
#       Customer service calls  Churn
# 10                         4   True
# 15                         4   True
# 21                         5   True
# 33                         1   True
# 41                         0   True
# ...                      ...    ...
# 3301                       0   True
# 3304                       4   True
# 3320                       4   True
# 3322                       4   True
# 3323                       5   True
#
# [483 rows x 20 columns]

# %%
f[f["Area code"] == 408]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3       OH              84        408                Yes              No
# 8       LA             117        408                 No              No
# 12      IA             168        408                 No              No
# 16      ID              85        408                 No             Yes
# 21      CO              77        408                 No              No
# ...    ...             ...        ...                ...             ...
# 3309    VT             100        408                Yes              No
# 3312    SC             181        408                 No              No
# 3313    ID             127        408                 No              No
# 3322    MD              62        408                 No              No
# 3325    OH              78        408                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3                         0              299.4               71
# 8                         0              184.5               97
# 12                        0              128.8               96
# 16                       27              196.4              139
# 21                        0               62.4               89
# ...                     ...                ...              ...
# 3309                      0              219.4              112
# 3312                      0              229.9              130
# 3313                      0              102.8              128
# 3322                      0              321.1              105
# 3325                      0              193.4               99
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3                50.90               61.9               88              5.26
# 8                31.37              351.6               80             29.89
# 12               21.90              104.9               71              8.92
# 16               33.39              280.9               90             23.88
# 21               10.61              169.9              121             14.44
# ...                ...                ...              ...               ...
# 3309             37.30              225.7              102             19.18
# 3312             39.08              144.4               93             12.27
# 3313             17.48              143.7               95             12.21
# 3322             54.59              265.5              122             22.57
# 3325             32.88              116.9               88              9.94
#
#       Total night minutes  Total night calls  Total night charge  \
# 3                   196.9                 89                8.86
# 8                   215.8                 90                9.71
# 12                  141.1                128                6.35
# 16                   89.3                 75                4.02
# 21                  209.6                 64                9.43
# ...                   ...                ...                 ...
# 3309                255.3                 95               11.49
# 3312                262.4                110               11.81
# 3313                191.4                 97                8.61
# 3322                180.5                 72                8.12
# 3325                243.3                109               10.95
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 3                    6.6                 7               1.78
# 8                    8.7                 4               2.35
# 12                  11.2                 2               3.02
# 16                  13.8                 4               3.73
# 21                   5.7                 6               1.54
# ...                  ...               ...                ...
# 3309                12.0                 4               3.24
# 3312                14.2                 4               3.83
# 3313                10.0                 5               2.70
# 3322                11.5                 2               3.11
# 3325                 9.3                 4               2.51
#
#       Customer service calls  Churn
# 3                          2  False
# 8                          1  False
# 12                         1  False
# 16                         1  False
# 21                         5   True
# ...                      ...    ...
# 3309                       4  False
# 3312                       2  False
# 3313                       1  False
# 3322                       4   True
# 3325                       2  False
#
# [838 rows x 20 columns]

# %%
f[f["Area code"] == 408].loc[3]
# Out:
# State                        OH
# Account length               84
# Area code                   408
# International plan          Yes
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         299.4
# Total day calls              71
# Total day charge           50.9
# Total eve minutes          61.9
# Total eve calls              88
# Total eve charge           5.26
# Total night minutes       196.9
# Total night calls            89
# Total night charge         8.86
# Total intl minutes          6.6
# Total intl calls              7
# Total intl charge          1.78
# Customer service calls        2
# Churn                     False
# Name: 3, dtype: object

# %%
f[f["Area code"] == 408].loc[3] == f[f["Area code"] == 408].iloc[0]
# Out:
# State                     True
# Account length            True
# Area code                 True
# International plan        True
# Voice mail plan           True
# Number vmail messages     True
# Total day minutes         True
# Total day calls           True
# Total day charge          True
# Total eve minutes         True
# Total eve calls           True
# Total eve charge          True
# Total night minutes       True
# Total night calls         True
# Total night charge        True
# Total intl minutes        True
# Total intl calls          True
# Total intl charge         True
# Customer service calls    True
# Churn                     True
# Name: 3, dtype: bool

# %%
f[f.Churn == True]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 10      IN              65        415                 No              No
# 15      NY             161        415                 No              No
# 21      CO              77        408                 No              No
# 33      AZ              12        408                 No              No
# 41      MD             135        408                Yes             Yes
# ...    ...             ...        ...                ...             ...
# 3301    CA              84        415                 No              No
# 3304    IL              71        510                Yes              No
# 3320    GA             122        510                Yes              No
# 3322    MD              62        408                 No              No
# 3323    IN             117        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 10                        0              129.1              137
# 15                        0              332.9               67
# 21                        0               62.4               89
# 33                        0              249.6              118
# 41                       41              173.1               85
# ...                     ...                ...              ...
# 3301                      0              280.0              113
# 3304                      0              186.1              114
# 3320                      0              140.0              101
# 3322                      0              321.1              105
# 3323                      0              118.4              126
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 10               21.95              228.5               83             19.42
# 15               56.59              317.8               97             27.01
# 21               10.61              169.9              121             14.44
# 33               42.43              252.4              119             21.45
# 41               29.43              203.9              107             17.33
# ...                ...                ...              ...               ...
# 3301             47.60              202.2               90             17.19
# 3304             31.64              198.6              140             16.88
# 3320             23.80              196.4               77             16.69
# 3322             54.59              265.5              122             22.57
# 3323             20.13              249.3               97             21.19
#
#       Total night minutes  Total night calls  Total night charge  \
# 10                  208.8                111                9.40
# 15                  160.6                128                7.23
# 21                  209.6                 64                9.43
# 33                  280.2                 90               12.61
# 41                  122.2                 78                5.50
# ...                   ...                ...                 ...
# 3301                156.8                103                7.06
# 3304                206.5                 80                9.29
# 3320                120.1                133                5.40
# 3322                180.5                 72                8.12
# 3323                227.0                 56               10.22
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 10                  12.7                 6               3.43
# 15                   5.4                 9               1.46
# 21                   5.7                 6               1.54
# 33                  11.8                 3               3.19
# 41                  14.6                15               3.94
# ...                  ...               ...                ...
# 3301                10.4                 4               2.81
# 3304                13.8                 5               3.73
# 3320                 9.7                 4               2.62
# 3322                11.5                 2               3.11
# 3323                13.6                 3               3.67
#
#       Customer service calls  Churn
# 10                         4   True
# 15                         4   True
# 21                         5   True
# 33                         1   True
# 41                         0   True
# ...                      ...    ...
# 3301                       0   True
# 3304                       4   True
# 3320                       4   True
# 3322                       4   True
# 3323                       5   True
#
# [483 rows x 20 columns]

# %%
f[f.Churn == True].mean()
# Out:
# Account length            102.664596
# Area code                 437.817805
# Number vmail messages       5.115942
# Total day minutes         206.914079
# Total day calls           101.335404
# Total day charge           35.175921
# Total eve minutes         212.410145
# Total eve calls           100.561077
# Total eve charge           18.054969
# Total night minutes       205.231677
# Total night calls         100.399586
# Total night charge          9.235528
# Total intl minutes         10.700000
# Total intl calls            4.163561
# Total intl charge           2.889545
# Customer service calls      2.229814
# Churn                       1.000000
# dtype: float64

# %%
f[f.Churn == True].sum()
# Out:
# State                     INNYCOAZMDIDWYCOTXDCNYTXINNJLAMSIDMENVMSMSVTOH...
# Account length                                                        49587
# Area code                                                            211466
# International plan        NoNoNoNoYesNoNoNoNoNoNoNoNoNoNoNoNoYesNoNoNoYe...
# Voice mail plan           NoNoNoNoYesNoNoYesNoNoNoNoNoNoNoNoNoYesNoNoYes...
# Number vmail messages                                                  2471
# Total day minutes                                                   99939.5
# Total day calls                                                       48945
# Total day charge                                                      16990
# Total eve minutes                                                    102594
# Total eve calls                                                       48571
# Total eve charge                                                    8720.55
# Total night minutes                                                 99126.9
# Total night calls                                                     48493
# Total night charge                                                  4460.76
# Total intl minutes                                                   5168.1
# Total intl calls                                                       2011
# Total intl charge                                                   1395.65
# Customer service calls                                                 1077
# Churn                                                                   483
# dtype: object

# %% [markdown]
# Выборка по нескольким условиям требует скобок, т.к. операции `&`, `|`, `~` (и, или, не) имеют более высокий приоритет, чем `==`, `>=`, `<=` и арифметические:

# %%
f[(f.Churn == True) & (f["Area code"] == 408)]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 21      CO              77        408                 No              No
# 33      AZ              12        408                 No              No
# 41      MD             135        408                Yes             Yes
# 57      CO             121        408                 No             Yes
# 77      NY             144        408                 No              No
# ...    ...             ...        ...                ...             ...
# 3151    ME              56        408                 No              No
# 3205    MS             111        408                 No              No
# 3246    NC              77        408                Yes             Yes
# 3280    AR              76        408                 No              No
# 3322    MD              62        408                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 21                        0               62.4               89
# 33                        0              249.6              118
# 41                       41              173.1               85
# 57                       30              198.4              129
# 77                        0               61.6              117
# ...                     ...                ...              ...
# 3151                      0              221.9              112
# 3205                      0              294.7               90
# 3246                     44              103.2              117
# 3280                      0              107.3              140
# 3322                      0              321.1              105
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 21               10.61              169.9              121             14.44
# 33               42.43              252.4              119             21.45
# 41               29.43              203.9              107             17.33
# 57               33.73               75.3               77              6.40
# 77               10.47               77.1               85              6.55
# ...                ...                ...              ...               ...
# 3151             37.72              278.2              122             23.65
# 3205             50.10              294.6               72             25.04
# 3246             17.54              236.3               86             20.09
# 3280             18.24              238.2              133             20.25
# 3322             54.59              265.5              122             22.57
#
#       Total night minutes  Total night calls  Total night charge  \
# 21                  209.6                 64                9.43
# 33                  280.2                 90               12.61
# 41                  122.2                 78                5.50
# 57                  181.2                 77                8.15
# 77                  173.0                 99                7.79
# ...                   ...                ...                 ...
# 3151                288.1                 85               12.96
# 3205                260.1                121               11.70
# 3246                203.5                101                9.16
# 3280                271.8                116               12.23
# 3322                180.5                 72                8.12
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 21                   5.7                 6               1.54
# 33                  11.8                 3               3.19
# 41                  14.6                15               3.94
# 57                   5.8                 3               1.57
# 77                   8.2                 7               2.21
# ...                  ...               ...                ...
# 3151                 7.1                 5               1.92
# 3205                10.8                 3               2.92
# 3246                11.9                 2               3.21
# 3280                10.0                 3               2.70
# 3322                11.5                 2               3.11
#
#       Customer service calls  Churn
# 21                         5   True
# 33                         1   True
# 41                         0   True
# 57                         3   True
# 77                         4   True
# ...                      ...    ...
# 3151                       0   True
# 3205                       1   True
# 3246                       0   True
# 3280                       4   True
# 3322                       4   True
#
# [122 rows x 20 columns]

# %% [markdown]
# Можем посмотреть средние показатели лояльных и нелояльных клиентов (столбец "Churn" показывает, ушел клиент от нас как от оператора связи или нет).

# %%
loyal = f[f.Churn == False].mean()
unloyal = f[f.Churn == True].mean()
pd.DataFrame({"loyal": loyal, "unloyal": unloyal})
# Out:
#                              loyal     unloyal
# Account length          100.793684  102.664596
# Area code               437.074737  437.817805
# Number vmail messages     8.604561    5.115942
# Total day minutes       175.175754  206.914079
# Total day calls         100.283158  101.335404
# Total day charge         29.780421   35.175921
# Total eve minutes       199.043298  212.410145
# Total eve calls         100.038596  100.561077
# Total eve charge         16.918909   18.054969
# Total night minutes     200.133193  205.231677
# Total night calls       100.058246  100.399586
# Total night charge        9.006074    9.235528
# Total intl minutes       10.158877   10.700000
# Total intl calls          4.532982    4.163561
# Total intl charge         2.743404    2.889545
# Customer service calls    1.449825    2.229814
# Churn                     0.000000    1.000000

# %% [markdown]
# `groupby` позволяет делать группировку по уникальным значениям столбца, которые будут играть роль индекса в полученном датафрейме. При этом также нужна функция агрегации (`mean`, `sum`, `max` и прочие), чтобы отобразить полученный объект.

# %%
f.groupby("Churn")

# %%
f.groupby("Churn").mean()
# Out:
#        Account length   Area code  Number vmail messages  Total day minutes  \
# Churn
# False      100.793684  437.074737               8.604561         175.175754
# True       102.664596  437.817805               5.115942         206.914079
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# Churn
# False       100.283158         29.780421         199.043298       100.038596
# True        101.335404         35.175921         212.410145       100.561077
#
#        Total eve charge  Total night minutes  Total night calls  \
# Churn
# False         16.918909           200.133193         100.058246
# True          18.054969           205.231677         100.399586
#
#        Total night charge  Total intl minutes  Total intl calls  \
# Churn
# False            9.006074           10.158877          4.532982
# True             9.235528           10.700000          4.163561
#
#        Total intl charge  Customer service calls
# Churn
# False           2.743404                1.449825
# True            2.889545                2.229814

# %% [markdown]
# Здесь мы сделали агрегацию всех столбцов функцией `mean`. Часто нам нужна агрегация по конкретному или конкретным столбцам. Посмотрим, например, в каком штате больше всего разговаривают по телефону:

# %%
f.groupby(["State"]).agg({"Total day minutes": "mean"})
# Out:
#        Total day minutes
# State
# AK            178.384615
# AL            186.010000
# AR            176.116364
# AZ            171.604687
# CA            183.564706
# CO            178.712121
# CT            175.140541
# DC            171.379630
# DE            174.583607
# FL            179.533333
# GA            185.025926
# HI            175.962264
# IA            177.613636
# ID            178.619178
# IL            173.591379
# IN            196.525352
# KS            191.555714
# KY            173.754237
# LA            178.376471
# MA            180.103077
# MD            197.228571
# ME            185.262903
# MI            180.593151
# MN            183.354762
# MO            170.506349
# MS            177.929231
# MT            174.007353
# NC            185.145588
# ND            187.338710
# NE            177.465574
# NH            177.328571
# NJ            196.225000
# NM            171.429032
# NV            176.425758
# NY            175.114458
# OH            183.274359
# OK            179.909836
# OR            176.246154
# PA            188.375556
# RI            167.478462
# SC            166.441667
# SD            189.690000
# TN            175.771698
# TX            181.516667
# UT            183.569444
# VA            177.244156
# VT            182.031507
# WA            178.742424
# WI            179.130769
# WV            173.950943
# WY            180.170130

# %% [markdown]
# Максимальное значение времени:

# %%
f.groupby(["State"]).agg({"Total day minutes": "mean"}).max()
# Out:
# Total day minutes    197.228571
# dtype: float64

# %% [markdown]
# Чтобы найти сам штат, можем отсортировать данные:

# %%
f.groupby(["State"]).agg({"Total day minutes": "mean"}).sort_values(by="Total day minutes", ascending = False)
# Out:
#        Total day minutes
# State
# MD            197.228571
# IN            196.525352
# NJ            196.225000
# KS            191.555714
# SD            189.690000
# PA            188.375556
# ND            187.338710
# AL            186.010000
# ME            185.262903
# NC            185.145588
# GA            185.025926
# UT            183.569444
# CA            183.564706
# MN            183.354762
# OH            183.274359
# VT            182.031507
# TX            181.516667
# MI            180.593151
# WY            180.170130
# MA            180.103077
# OK            179.909836
# FL            179.533333
# WI            179.130769
# WA            178.742424
# CO            178.712121
# ID            178.619178
# AK            178.384615
# LA            178.376471
# MS            177.929231
# IA            177.613636
# NE            177.465574
# NH            177.328571
# VA            177.244156
# NV            176.425758
# OR            176.246154
# AR            176.116364
# HI            175.962264
# TN            175.771698
# CT            175.140541
# NY            175.114458
# DE            174.583607
# MT            174.007353
# WV            173.950943
# KY            173.754237
# IL            173.591379
# AZ            171.604687
# NM            171.429032
# DC            171.379630
# MO            170.506349
# RI            167.478462
# SC            166.441667

# %% [markdown]
# **Пример.** Как распределен отток клиентов по штатам? В каких штатах он больше среднего?

# %%
f.groupby(["State"]).agg({"Churn": "mean"})
# Out:
#           Churn
# State
# AK     0.057692
# AL     0.100000
# AR     0.200000
# AZ     0.062500
# CA     0.264706
# CO     0.136364
# CT     0.162162
# DC     0.092593
# DE     0.147541
# FL     0.126984
# GA     0.148148
# HI     0.056604
# IA     0.068182
# ID     0.123288
# IL     0.086207
# IN     0.126761
# KS     0.185714
# KY     0.135593
# LA     0.078431
# MA     0.169231
# MD     0.242857
# ME     0.209677
# MI     0.219178
# MN     0.178571
# MO     0.111111
# MS     0.215385
# MT     0.205882
# NC     0.161765
# ND     0.096774
# NE     0.081967
# NH     0.160714
# NJ     0.264706
# NM     0.096774
# NV     0.212121
# NY     0.180723
# OH     0.128205
# OK     0.147541
# OR     0.141026
# PA     0.177778
# RI     0.092308
# SC     0.233333
# SD     0.133333
# TN     0.094340
# TX     0.250000
# UT     0.138889
# VA     0.064935
# VT     0.109589
# WA     0.212121
# WI     0.089744
# WV     0.094340
# WY     0.116883

# %%
f.groupby(["State"]).agg({"Churn": "mean"}).loc["LA"]
# Out:
# Churn    0.078431
# Name: LA, dtype: float64

# %%
f.groupby(["State"]).agg({"Churn": "mean"}).mean()
# Out:
# Churn    0.144927
# dtype: float64

# %%
f.groupby(["State"]).agg({"Churn": "mean"}).mean()[0]
# Out:
# 0.14492688214643257

# %%
m = f.groupby(["State"]).agg({"Churn": "mean"}).mean()[0]
new_dataframe = f.groupby(["State"]).agg({"Churn": "mean"})
new_dataframe[new_dataframe.Churn > m]
# Out:
#           Churn
# State
# AR     0.200000
# CA     0.264706
# CT     0.162162
# DE     0.147541
# GA     0.148148
# KS     0.185714
# MA     0.169231
# MD     0.242857
# ME     0.209677
# MI     0.219178
# MN     0.178571
# MS     0.215385
# MT     0.205882
# NC     0.161765
# NH     0.160714
# NJ     0.264706
# NV     0.212121
# NY     0.180723
# OK     0.147541
# PA     0.177778
# SC     0.233333
# TX     0.250000
# WA     0.212121

# %% [markdown]
# ## Упражнения.

# %% [markdown]
# **Упражнение 3.** Найдите среднее количество звонков `Total day calls` для всего датафрейма.

# %%
f.groupby(["State"]).agg({"Total day calls": "mean"}).mean()
# Out:
# Total day calls    100.467658
# dtype: float64

# %% [markdown]
# **Упражнение 4.** Найдите среднее количество звонков `Total day calls` для любого выбранного вами штата.

# %%
f.groupby(["State"]).agg({"Total day calls": "mean"}).loc["SC"]
# Out:
# Total day calls    102.466667
# Name: SC, dtype: float64

# %% [markdown]
# **Упражнение 5.** Создайте датафрейм, в котором будет среднее количество звонков `Total day calls` для каждого штата.

# %%
df_tdc = f.groupby(["State"]).agg({"Total day calls": "mean"})
df_tdc
# Out:
#        Total day calls
# State
# AK           95.269231
# AL           99.100000
# AR          102.145455
# AZ          100.109375
# CA          104.500000
# CO           95.121212
# CT           98.432432
# DC          100.166667
# DE           98.639344
# FL          101.000000
# GA          103.055556
# HI          102.811321
# IA          103.045455
# ID          106.219178
# IL          101.689655
# IN          107.056338
# KS          101.028571
# KY          100.338983
# LA          103.509804
# MA          102.292308
# MD           99.357143
# ME           99.500000
# MI          101.205479
# MN           99.119048
# MO           99.936508
# MS          100.707692
# MT           95.220588
# NC          102.794118
# ND          100.145161
# NE           97.409836
# NH           98.964286
# NJ          100.102941
# NM          102.241935
# NV          101.424242
# NY           98.240964
# OH           99.628205
# OK          100.262295
# OR           95.730769
# PA           98.644444
# RI          100.430769
# SC          102.466667
# SD           94.816667
# TN          101.452830
# TX           99.986111
# UT           98.958333
# VA          105.363636
# VT          100.328767
# WA          101.196970
# WI           96.679487
# WV          103.783019
# WY          102.220779

# %% [markdown]
# **Упражнение 6.** Оставьте в созданном датафрейме строки только с теми штатами, где количество звонков `Total day calls` больше среднего по исходному датафрейму.

# %%
m = f.groupby(["State"]).agg({"Total day calls": "mean"}).mean()[0]

df_tdc[df_tdc["Total day calls"] > m]
# Out:
#        Total day calls
# State
# AR          102.145455
# CA          104.500000
# FL          101.000000
# GA          103.055556
# HI          102.811321
# IA          103.045455
# ID          106.219178
# IL          101.689655
# IN          107.056338
# KS          101.028571
# LA          103.509804
# MA          102.292308
# MI          101.205479
# MS          100.707692
# NC          102.794118
# NM          102.241935
# NV          101.424242
# SC          102.466667
# TN          101.452830
# VA          105.363636
# WA          101.196970
# WV          103.783019
# WY          102.220779

# %% [markdown]
# **Упражнение 7.** Создайте датафрейм, в котором будует средние количества звонков `Total day calls` и `Total eve calls` для каждого штата.

# %%
df_tdec = f.groupby(["State"]).agg({"Total eve calls": "mean"})


df_tdec["Total day calls"] = df_tdc
df_tdec["Total eve calls"] = df_tec


df_tdec
# Out:
#        Total eve calls  Total day calls
# State
# AK           96.576923        95.269231
# AL           98.462500        99.100000
# AR           97.836364       102.145455
# AZ          102.406250       100.109375
# CA          103.088235       104.500000
# CO           98.166667        95.121212
# CT           99.121622        98.432432
# DC          101.981481       100.166667
# DE           97.360656        98.639344
# FL          108.920635       101.000000
# GA          103.888889       103.055556
# HI           98.849057       102.811321
# IA           99.545455       103.045455
# ID          100.054795       106.219178
# IL          100.810345       101.689655
# IN           97.943662       107.056338
# KS          101.528571       101.028571
# KY           98.237288       100.338983
# LA           96.627451       103.509804
# MA           98.230769       102.292308
# MD           98.571429        99.357143
# ME          104.596774        99.500000
# MI          101.986301       101.205479
# MN          101.642857        99.119048
# MO          101.047619        99.936508
# MS          100.200000       100.707692
# MT           97.514706        95.220588
# NC          103.941176       102.794118
# ND          105.467742       100.145161
# NE          103.590164        97.409836
# NH           95.803571        98.964286
# NJ          103.441176       100.102941
# NM          102.983871       102.241935
# NV           96.257576       101.424242
# NY          100.024096        98.240964
# OH          101.205128        99.628205
# OK          104.278689       100.262295
# OR           98.500000        95.730769
# PA          101.622222        98.644444
# RI           94.969231       100.430769
# SC           99.783333       102.466667
# SD           98.633333        94.816667
# TN          103.754717       101.452830
# TX          101.902778        99.986111
# UT           98.027778        98.958333
# VA           99.948052       105.363636
# VT           97.671233       100.328767
# WA           95.742424       101.196970
# WI           99.538462        96.679487
# WV           98.056604       103.783019
# WY           99.233766       102.220779

# %% [markdown]
# **Упражнение 8.** Создайте датафрейм, в котором будует средние количества звонков `Total day calls` и `Total eve calls` для каждого штата, а также столбец со значениями True и False - ответом на вопрос, больше ли дневных звонков, чем вечерних.

# %%
df_tdec["Is day calls more"] = (df_tdec["Total day calls"] > df_tdec["Total eve calls"])
df_tdec
# Out:
#        Total eve calls  Total day calls  Is day calls more
# State
# AK           96.576923        95.269231              False
# AL           98.462500        99.100000               True
# AR           97.836364       102.145455               True
# AZ          102.406250       100.109375              False
# CA          103.088235       104.500000               True
# CO           98.166667        95.121212              False
# CT           99.121622        98.432432              False
# DC          101.981481       100.166667              False
# DE           97.360656        98.639344               True
# FL          108.920635       101.000000              False
# GA          103.888889       103.055556              False
# HI           98.849057       102.811321               True
# IA           99.545455       103.045455               True
# ID          100.054795       106.219178               True
# IL          100.810345       101.689655               True
# IN           97.943662       107.056338               True
# KS          101.528571       101.028571              False
# KY           98.237288       100.338983               True
# LA           96.627451       103.509804               True
# MA           98.230769       102.292308               True
# MD           98.571429        99.357143               True
# ME          104.596774        99.500000              False
# MI          101.986301       101.205479              False
# MN          101.642857        99.119048              False
# MO          101.047619        99.936508              False
# MS          100.200000       100.707692               True
# MT           97.514706        95.220588              False
# NC          103.941176       102.794118              False
# ND          105.467742       100.145161              False
# NE          103.590164        97.409836              False
# NH           95.803571        98.964286               True
# NJ          103.441176       100.102941              False
# NM          102.983871       102.241935              False
# NV           96.257576       101.424242               True
# NY          100.024096        98.240964              False
# OH          101.205128        99.628205              False
# OK          104.278689       100.262295              False
# OR           98.500000        95.730769              False
# PA          101.622222        98.644444              False
# RI           94.969231       100.430769               True
# SC           99.783333       102.466667               True
# SD           98.633333        94.816667              False
# TN          103.754717       101.452830              False
# TX          101.902778        99.986111              False
# UT           98.027778        98.958333               True
# VA           99.948052       105.363636               True
# VT           97.671233       100.328767               True
# WA           95.742424       101.196970               True
# WI           99.538462        96.679487              False
# WV           98.056604       103.783019               True
# WY           99.233766       102.220779               True

# %% [markdown]
# **Упражнение 9.** Найти долю клиентов (отношение их числа к общему количеству клиентов) с `international plan` и `voice mail plan`.

# %%
intp = (f[f["International plan"] == "Yes"].size)/20
vmp = (f[f["Voice mail plan"] == "Yes"].size)/20

all_n= f.size/20

intp_v = intp/all_n
vmp_v = vmp/all_n
print(intp_v, vmp_v)
# Out:
# 0.0969096909690969 0.27662766276627665

# %% [markdown]
# **Упражнение 10.** Найти число уникальных значений `Area code`.

# %%
f["Area code"].unique()
# Out:
# array([415, 408, 510], dtype=int64)

# %% [markdown]
# **Упражнение 11.** Вывести DataFrame из 2 столбцов: число звонков в поддержку; число клиентов, звонивших столько раз. Подсказка: используйте функцию агрегации `count`.

# %%
df_csc = f.agg("Customer service calls")
f["Customer service calls"].unique()

arr = f["Customer service calls"].unique()
a = []
for i in arr:
    
    num = f[f["Customer service calls"] == i].count()[0]
    a.append(num)



df = pd.DataFrame({"Number of calls": arr, "Number of people": a}).sort_values(by="Number of calls", ascending = True)

df
# Out:
#    Number of calls  Number of people
# 1                0               697
# 0                1              1181
# 2                2               759
# 3                3               429
# 4                4               166
# 5                5                66
# 8                6                22
# 6                7                 9
# 9                8                 2
# 7                9                 2

# %% [markdown]
# **Упражнение 12.** Вывести DataFrame из 2 столбцов: число звонков в поддержку; доля оттока (`Churn`). Построить график.

# %%
f['Customer service calls'].value_counts('Churn')
# Out:
# 1    0.354335
# 2    0.227723
# 0    0.209121
# 3    0.128713
# 4    0.049805
# 5    0.019802
# 6    0.006601
# 7    0.002700
# 9    0.000600
# 8    0.000600
# Name: Customer service calls, dtype: float64

# %%
f
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1              110
# 1                        26              161.6              123
# 2                         0              243.4              114
# 3                         0              299.4               71
# 4                         0              166.7              113
# ...                     ...                ...              ...
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0                45.07              197.4               99             16.78
# 1                27.47              195.5              103             16.62
# 2                41.38              121.2              110             10.30
# 3                50.90               61.9               88              5.26
# 4                28.34              148.3              122             12.61
# ...                ...                ...              ...               ...
# 3328             26.55              215.5              126             18.32
# 3329             39.29              153.4               55             13.04
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# ...                   ...                ...                 ...
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 0                          1  False
# 1                          1  False
# 2                          0  False
# 3                          2  False
# 4                          3  False
# ...                      ...    ...
# 3328                       2  False
# 3329                       3  False
# 3330                       2  False
# 3331                       2  False
# 3332                       0  False
#
# [3333 rows x 20 columns]

# %% [markdown]
# **Упражнение 13.** Найти среднюю длительность международного (`intl`) звонка.

# %%
df_new = f.agg({"Total intl minutes":"mean"})
df_new[0]
# Out:
# 10.237293729372938

# %% [markdown]
# **Упражнение 14*.** Какие звонки дольше - дневные, вечерние или ночные? Ответ привести в формате DataFrame $3*3$: строки - число минут, число звонков, среднее время звонка. Столбцы - день, вечер, ночь

# %% [markdown]
# **Упражнение 15.** Сравнить `Total day charge` для оставшихся и ушедших клиентов.

# %%
df_m = f.groupby("Churn").mean()

df_m["Total day charge"]
# Out:
# Churn
# False    29.780421
# True     35.175921
# Name: Total day charge, dtype: float64

# %% [markdown]
# **Упражнение 16.** Отсортриуйте штаты по `Total day charge` (по возрастанию).

# %%
f.groupby(["State"]).agg({"Total day minutes": "mean"}).sort_values(by="Total day minutes", ascending = True)
# Out:
#        Total day minutes
# State
# SC            166.441667
# RI            167.478462
# MO            170.506349
# DC            171.379630
# NM            171.429032
# AZ            171.604688
# IL            173.591379
# KY            173.754237
# WV            173.950943
# MT            174.007353
# DE            174.583607
# NY            175.114458
# CT            175.140541
# TN            175.771698
# HI            175.962264
# AR            176.116364
# OR            176.246154
# NV            176.425758
# VA            177.244156
# NH            177.328571
# NE            177.465574
# IA            177.613636
# MS            177.929231
# LA            178.376471
# AK            178.384615
# ID            178.619178
# CO            178.712121
# WA            178.742424
# WI            179.130769
# FL            179.533333
# OK            179.909836
# MA            180.103077
# WY            180.170130
# MI            180.593151
# TX            181.516667
# VT            182.031507
# OH            183.274359
# MN            183.354762
# CA            183.564706
# UT            183.569444
# GA            185.025926
# NC            185.145588
# ME            185.262903
# AL            186.010000
# ND            187.338710
# PA            188.375556
# SD            189.690000
# KS            191.555714
# NJ            196.225000
# IN            196.525352
# MD            197.228571

# %% [markdown]
# **Упражнение 17.** Сделайте агрегацию по средним показателям для каждой `Area code`.

# %%
df_new = f.groupby(["Area code"]).agg("mean")
df_new
# Out:
#            Account length  Number vmail messages  Total day minutes  \
# Area code
# 408            101.877088               7.668258         177.175418
# 415            101.068882               8.357704         181.592628
# 510            100.246429               8.019048         178.787619
#
#            Total day calls  Total day charge  Total eve minutes  \
# Area code
# 408             100.496420         30.120274         201.284248
# 415             100.576435         30.871335         200.652085
# 510             100.097619         30.394429         201.323929
#
#            Total eve calls  Total eve charge  Total night minutes  \
# Area code
# 408              99.788783         17.109308           199.214678
# 415             100.503927         17.055571           202.037583
# 510              99.671429         17.112940           200.229048
#
#            Total night calls  Total night charge  Total intl minutes  \
# Area code
# 408                99.039379            8.964785           10.126372
# 415               100.398187            9.091795           10.343444
# 510               100.601190            9.010310           10.138810
#
#            Total intl calls  Total intl charge  Customer service calls  \
# Area code
# 408                4.426014           2.734737                1.519093
# 415                4.561934           2.793257                1.554079
# 510                4.370238           2.737857                1.623810
#
#               Churn
# Area code
# 408        0.145585
# 415        0.142598
# 510        0.148810

# %% [markdown]
# **Упражнение 18.** Выведите датафрейм размера $3*2$: столбцы State, Churn для 100, 102 и 104 строк исходного датафрейма.

# %%
df_n = f.iloc[100:101]
df_a = f.iloc[102:103]
df_c = f.iloc[104:105]
df_n = df_n.append(df_a)
df_n = df_n.append(df_c)
df_total = df_n[['State', 'Churn']].copy()
df_total
# Out:
# <ipython-input-25-2921f5ce5404>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_n = df_n.append(df_a)
# <ipython-input-25-2921f5ce5404>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_n = df_n.append(df_c)
#     State  Churn
# 100    IA  False
# 102    VT  False
# 104    IN  False

# %% [markdown]
# **Упражнение 19.** Создайте датафрейм из 2 столбцов, заполненных произвольными числами. Добавьте третий столбец, равный их сумме квадратов.

# %%
df = pd.DataFrame({"A": [13, 15, 42, 57], "B": [5, 4, 12, 43]})
df["C"] = df[["A", "B"]].apply(lambda x: (x**2).sum(), axis=1)
df
# Out:
#     A   B     C
# 0  13   5   194
# 1  15   4   241
# 2  42  12  1908
# 3  57  43  5098

# %% [markdown]
# **Упражнение 20.** Добавьте к созданному датафрейму четвертый столбец, равный среднему значению первых трех, *используя* функцию `mean`.

# %%
df["D"] = df[["A", "B", "C"]].apply(lambda x: (x).mean(), axis=1)
df
# Out:
#     A   B     C            D
# 0  13   5   194    70.666667
# 1  15   4   241    86.666667
# 2  42  12  1908   654.000000
# 3  57  43  5098  1732.666667
